# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from IPython.display import HTML
from base64 import b64encode

## play_video function based on: https://colab.research.google.com/drive/1bNXkfpHiVHzXQH8WjGhzQ-fsDxolpUjD

def play_video(video_path, width=200):
  mp4 = open(video_path,'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
  return HTML(f"""
  <video width={width} controls>
        <source src="{data_url}" type="video/mp4">
  </video>
  """)

# %%
play_video('/content/drive/MyDrive/FinalAL/1/2.mp4', width=300)
# Out:
#   <video width=300 controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#   </video>

# %%
# %cd "/content/"
# !git clone https://github.com/mpc001/Visual_Speech_Recognition_for_Multiple_Languages.git
# %cd "Visual_Speech_Recognition_for_Multiple_Languages"
# Out:
# /content
# Cloning into 'Visual_Speech_Recognition_for_Multiple_Languages'...
# remote: Enumerating objects: 277, done.
# remote: Counting objects: 100% (100/100), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 277 (delta 33), reused 81 (delta 22), pack-reused 177
# Receiving objects: 100% (277/277), 69.77 MiB | 26.51 MiB/s, done.
# Resolving deltas: 100% (58/58), done.
# /content/Visual_Speech_Recognition_for_Multiple_Languages

# %%
# !pip install av
# !pip install mediapipe
# !pip install ffmpeg-python
# Out:
# Collecting av
#   Downloading av-11.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (32.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 11.9 MB/s eta 0:00:00
# Installing collected packages: av
# Successfully installed av-11.0.0
# Collecting mediapipe
#   Downloading mediapipe-0.10.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (23.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mediapipe) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.23.5)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mediapipe) (4.8.0.76)
# Requirement already satisfied: protobuf<4,>=3.11 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (3.20.3)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.4.6-py3-none-any.whl (31 kB)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Installing collected packages: sounddevice, mediapipe
# Successfully installed mediapipe-0.10.9 sounddevice-0.4.6
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from ffmpeg-python) (0.18.3)
# Installing collected packages: ffmpeg-python
# Successfully installed ffmpeg-python-0.2.0

# %%
import os
import torch
from pipelines.model import AVSR
from pipelines.data.data_module import AVSRDataLoader
from pipelines.detectors.mediapipe.detector import LandmarksDetector

class InferencePipeline(torch.nn.Module):
    def __init__(self, modality, model_path, model_conf, detector="mediapipe", face_track=False, device="cuda:0"):
        super(InferencePipeline, self).__init__()
        self.device = device
        # modality configuration
        self.modality = modality
        self.dataloader = AVSRDataLoader(modality, detector=detector)
        self.model = AVSR(modality, model_path, model_conf, rnnlm=None, rnnlm_conf=None, penalty=0.0, ctc_weight=0.1, lm_weight=0.0, beam_size=40, device=device)
        if face_track and self.modality in ["video", "audiovisual"]:
            self.landmarks_detector = LandmarksDetector()
        else:
            self.landmarks_detector = None


    def process_landmarks(self, data_filename, landmarks_filename):
        if self.modality == "audio":
            return None
        if self.modality in ["video", "audiovisual"]:
            landmarks = self.landmarks_detector(data_filename)
            return landmarks


    def forward(self, data_filename, landmarks_filename=None):
        assert os.path.isfile(data_filename), f"data_filename: {data_filename} does not exist."
        landmarks = self.process_landmarks(data_filename, landmarks_filename)
        data = self.dataloader.load_data(data_filename, landmarks)
        transcript = self.model.infer(data)
        return transcript

    def extract_features(self, data_filename, landmarks_filename=None, extract_resnet_feats=False):
        assert os.path.isfile(data_filename), f"data_filename: {data_filename} does not exist."
        landmarks = self.process_landmarks(data_filename, landmarks_filename)
        data = self.dataloader.load_data(data_filename, landmarks)
        with torch.no_grad():
            if isinstance(data, tuple):
                enc_feats = self.model.model.encode(data[0].to(self.device), data[1].to(self.device), extract_resnet_feats)
            else:
                enc_feats = self.model.model.encode(data.to(self.device), extract_resnet_feats)
        return enc_feats

# %%
# %mkdir -p /content/data/
# !wget http://www.doc.ic.ac.uk/~pm4115/autoAVSR/LRS3_V_WER19.1.zip -O /content/data/LRS3_V_WER19.1.zip
# !unzip -o /content/data/LRS3_V_WER19.1.zip -d /content/data/
# Out:
# --2024-01-05 14:53:15--  http://www.doc.ic.ac.uk/~pm4115/autoAVSR/LRS3_V_WER19.1.zip
# Resolving www.doc.ic.ac.uk (www.doc.ic.ac.uk)... 146.169.13.6
# Connecting to www.doc.ic.ac.uk (www.doc.ic.ac.uk)|146.169.13.6|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 937274463 (894M) [application/zip]
# Saving to: ‘/content/data/LRS3_V_WER19.1.zip’
#
# /content/data/LRS3_ 100%[===================>] 893.85M  9.38MB/s    in 63s
#
# 2024-01-05 14:54:19 (14.1 MB/s) - ‘/content/data/LRS3_V_WER19.1.zip’ saved [937274463/937274463]
#
# Archive:  /content/data/LRS3_V_WER19.1.zip
#   inflating: /content/data/LRS3_V_WER19.1/model.json
#   inflating: /content/data/LRS3_V_WER19.1/model.pth

# %%
modality = "video"
model_conf = "/content/data/LRS3_V_WER19.1/model.json"
model_path = "/content/data/LRS3_V_WER19.1/model.pth"
pipeline = InferencePipeline(modality, model_path, model_conf, face_track=True)

# %%
import cv2
import torchvision
from pipelines.data.data_module import AVSRDataLoader
from pipelines.detectors.mediapipe.detector import LandmarksDetector

def save2vid(filename, vid, frames_per_second):
    os.makedirs(os.path.dirname(filename), exist_ok=True)
    torchvision.io.write_video(filename, vid, frames_per_second)

def preprocess_video(src_filename, dst_filename):
    landmarks = landmarks_detector(src_filename)
    data = dataloader.load_data(src_filename, landmarks)
    fps = cv2.VideoCapture(src_filename).get(cv2.CAP_PROP_FPS)
    save2vid(dst_filename, data, fps)
    return

dataloader = AVSRDataLoader(modality="video", speed_rate=1, transform=False, detector="mediapipe", convert_gray=False)
landmarks_detector = LandmarksDetector()

# %%
# !mkdir /content/data/roi_clips/

# %%
import os
import os.path

for dirpath, dirnames, filenames in os.walk("/content/drive/MyDrive/FinalAL/"):
    for filename in [f for f in filenames if f.endswith(".mp4")]:
        src_vid_path = (os.path.join(dirpath, filename))
        preprocess_video(src_filename=src_vid_path, dst_filename="/content/data/roi_clips/{}_{}.mp4".format(src_vid_path.split("/")[-2],src_vid_path.split("/")[-1][:-4]))

# %%
# !zip /content/data/roi_clips.zip -r /content/data/roi_clips
# Out:
#   adding: content/data/roi_clips/ (stored 0%)
#   adding: content/data/roi_clips/9_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/23_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/4_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/10_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/21_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/8_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/7_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/28_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/2_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/26_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/15_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/16_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/25_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/19_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/21_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/28_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/14_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/20_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/11_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/4_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/13_6.mp4 (deflated 9%)
#   adding: content/data/roi_clips/23_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/21_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/5_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/19_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/6_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/4_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/1_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/11_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/10_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/24_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/6_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/8_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/8_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/13_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/1_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/14_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/9_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/8_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/15_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/8_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/11_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/12_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/28_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/21_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/19_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/16_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/19_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/12_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/2_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/28_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/24_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/11_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/17_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/20_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/17_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/19_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/1_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/4_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/22_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/4_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/13_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/11_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/13_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/9_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/23_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/27_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/11_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/9_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/18_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/8_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/16_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/16_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/17_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/1_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/22_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/15_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/20_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/7_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/15_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/25_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/21_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/23_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/16_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/9_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/25_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/18_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/21_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/7_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/26_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/3_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/18_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/28_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/14_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/22_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/4_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/10_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/27_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/24_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/6_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/5_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/26_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/22_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/17_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/24_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/27_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/12_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/7_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/1_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/25_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/25_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/9_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/26_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/4_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/22_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/3_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/13_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/23_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/2_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/28_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/18_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/28_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/14_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/2_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/8_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/19_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/6_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/3_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/19_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/27_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/24_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/21_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/25_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/5_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/10_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/7_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/19_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/27_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/20_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/5_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/7_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/3_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/5_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/5_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/20_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/27_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/3_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/10_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/19_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/3_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/13_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/6_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/20_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/26_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/1_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/6_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/10_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/8_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/18_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/20_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/20_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/10_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/16_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/9_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/15_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/1_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/11_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/1_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/27_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/2_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/13_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/16_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/18_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/10_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/17_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/27_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/27_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/26_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/13_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/26_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/5_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/25_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/11_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/9_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/4_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/14_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/3_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/22_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/20_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/26_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/15_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/9_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/1_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/18_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/8_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/28_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/2_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/23_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/13_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/17_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/11_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/23_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/18_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/25_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/3_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/5_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/8_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/15_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/22_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/15_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/10_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/9_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/7_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/14_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/23_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/23_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/16_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/2_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/22_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/2_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/22_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/7_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/6_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/12_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/12_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/26_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/2_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/18_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/24_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/14_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/20_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/28_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/12_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/15_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/6_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/12_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/24_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/19_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/13_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/17_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/12_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/24_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/21_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/4_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/5_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/26_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/15_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/24_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/7_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/12_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/23_3.mp4 (deflated 1%)
#   adding: content/data/roi_clips/14_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/5_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/6_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/25_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/17_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/7_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/3_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/4_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/25_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/22_6.mp4 (deflated 1%)
#   adding: content/data/roi_clips/17_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/27_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/18_7.mp4 (deflated 1%)
#   adding: content/data/roi_clips/2_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/14_1.mp4 (deflated 1%)
#   adding: content/data/roi_clips/3_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/21_10.mp4 (deflated 1%)
#   adding: content/data/roi_clips/10_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/24_2.mp4 (deflated 1%)
#   adding: content/data/roi_clips/28_9.mp4 (deflated 1%)
#   adding: content/data/roi_clips/11_8.mp4 (deflated 1%)
#   adding: content/data/roi_clips/1_4.mp4 (deflated 1%)
#   adding: content/data/roi_clips/14_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/16_5.mp4 (deflated 1%)
#   adding: content/data/roi_clips/12_3.mp4 (deflated 1%)

# %%
# !unzip /content/data/roi_clips_clean.zip -d /content/data/
# Out:
# Archive:  /content/data/roi_clips_clean.zip
#   inflating: /content/data/roi_clips_clean/1_10.mp4
#   inflating: /content/data/roi_clips_clean/1_5.mp4
#   inflating: /content/data/roi_clips_clean/1_6.mp4
#   inflating: /content/data/roi_clips_clean/1_7.mp4
#   inflating: /content/data/roi_clips_clean/1_9.mp4
#   inflating: /content/data/roi_clips_clean/10_1.mp4
#   inflating: /content/data/roi_clips_clean/10_4.mp4
#   inflating: /content/data/roi_clips_clean/10_5.mp4
#   inflating: /content/data/roi_clips_clean/10_6.mp4
#   inflating: /content/data/roi_clips_clean/10_7.mp4
#   inflating: /content/data/roi_clips_clean/10_8.mp4
#   inflating: /content/data/roi_clips_clean/11_10.mp4
#   inflating: /content/data/roi_clips_clean/11_4.mp4
#   inflating: /content/data/roi_clips_clean/11_5.mp4
#   inflating: /content/data/roi_clips_clean/11_7.mp4
#   inflating: /content/data/roi_clips_clean/11_8.mp4
#   inflating: /content/data/roi_clips_clean/12_1.mp4
#   inflating: /content/data/roi_clips_clean/12_10.mp4
#   inflating: /content/data/roi_clips_clean/12_5.mp4
#   inflating: /content/data/roi_clips_clean/12_6.mp4
#   inflating: /content/data/roi_clips_clean/12_7.mp4
#   inflating: /content/data/roi_clips_clean/12_8.mp4
#   inflating: /content/data/roi_clips_clean/12_9.mp4
#   inflating: /content/data/roi_clips_clean/13_1.mp4
#   inflating: /content/data/roi_clips_clean/13_10.mp4
#   inflating: /content/data/roi_clips_clean/13_2.mp4
#   inflating: /content/data/roi_clips_clean/13_6.mp4
#   inflating: /content/data/roi_clips_clean/13_7.mp4
#   inflating: /content/data/roi_clips_clean/13_8.mp4
#   inflating: /content/data/roi_clips_clean/14_1.mp4
#   inflating: /content/data/roi_clips_clean/14_10.mp4
#   inflating: /content/data/roi_clips_clean/14_6.mp4
#   inflating: /content/data/roi_clips_clean/14_7.mp4
#   inflating: /content/data/roi_clips_clean/14_8.mp4
#   inflating: /content/data/roi_clips_clean/15_10.mp4
#   inflating: /content/data/roi_clips_clean/15_3.mp4
#   inflating: /content/data/roi_clips_clean/15_4.mp4
#   inflating: /content/data/roi_clips_clean/15_5.mp4
#   inflating: /content/data/roi_clips_clean/15_6.mp4
#   inflating: /content/data/roi_clips_clean/16_10.mp4
#   inflating: /content/data/roi_clips_clean/16_4.mp4
#   inflating: /content/data/roi_clips_clean/16_5.mp4
#   inflating: /content/data/roi_clips_clean/16_6.mp4
#   inflating: /content/data/roi_clips_clean/16_7.mp4
#   inflating: /content/data/roi_clips_clean/16_9.mp4
#   inflating: /content/data/roi_clips_clean/17_10.mp4
#   inflating: /content/data/roi_clips_clean/17_3.mp4
#   inflating: /content/data/roi_clips_clean/17_5.mp4
#   inflating: /content/data/roi_clips_clean/17_6.mp4
#   inflating: /content/data/roi_clips_clean/26_5.mp4
#   inflating: /content/data/roi_clips_clean/26_6.mp4
#   inflating: /content/data/roi_clips_clean/26_7.mp4
#   inflating: /content/data/roi_clips_clean/26_8.mp4
#   inflating: /content/data/roi_clips_clean/27_10.mp4
#   inflating: /content/data/roi_clips_clean/27_5.mp4
#   inflating: /content/data/roi_clips_clean/27_6.mp4
#   inflating: /content/data/roi_clips_clean/27_7.mp4
#   inflating: /content/data/roi_clips_clean/27_8.mp4
#   inflating: /content/data/roi_clips_clean/28_10.mp4
#   inflating: /content/data/roi_clips_clean/28_2.mp4
#   inflating: /content/data/roi_clips_clean/28_3.mp4
#   inflating: /content/data/roi_clips_clean/28_6.mp4
#   inflating: /content/data/roi_clips_clean/28_7.mp4
#   inflating: /content/data/roi_clips_clean/28_8.mp4
#   inflating: /content/data/roi_clips_clean/3_2.mp4
#   inflating: /content/data/roi_clips_clean/3_3.mp4
#   inflating: /content/data/roi_clips_clean/3_5.mp4
#   inflating: /content/data/roi_clips_clean/3_6.mp4
#   inflating: /content/data/roi_clips_clean/3_7.mp4
#   inflating: /content/data/roi_clips_clean/4_10.mp4
#   inflating: /content/data/roi_clips_clean/4_5.mp4
#   inflating: /content/data/roi_clips_clean/4_6.mp4
#   inflating: /content/data/roi_clips_clean/4_7.mp4
#   inflating: /content/data/roi_clips_clean/4_8.mp4
#   inflating: /content/data/roi_clips_clean/4_9.mp4
#   inflating: /content/data/roi_clips_clean/5_1.mp4
#   inflating: /content/data/roi_clips_clean/5_10.mp4
#   inflating: /content/data/roi_clips_clean/5_5.mp4
#   inflating: /content/data/roi_clips_clean/5_6.mp4
#   inflating: /content/data/roi_clips_clean/5_7.mp4
#   inflating: /content/data/roi_clips_clean/5_8.mp4
#   inflating: /content/data/roi_clips_clean/6_1.mp4
#   inflating: /content/data/roi_clips_clean/6_10.mp4
#   inflating: /content/data/roi_clips_clean/6_3.mp4
#   inflating: /content/data/roi_clips_clean/6_4.mp4
#   inflating: /content/data/roi_clips_clean/6_5.mp4
#   inflating: /content/data/roi_clips_clean/6_6.mp4
#   inflating: /content/data/roi_clips_clean/7_10.mp4
#   inflating: /content/data/roi_clips_clean/7_5.mp4
#   inflating: /content/data/roi_clips_clean/7_6.mp4
#   inflating: /content/data/roi_clips_clean/7_7.mp4
#   inflating: /content/data/roi_clips_clean/7_8.mp4
#   inflating: /content/data/roi_clips_clean/8_10.mp4
#   inflating: /content/data/roi_clips_clean/8_4.mp4
#   inflating: /content/data/roi_clips_clean/8_5.mp4
#   inflating: /content/data/roi_clips_clean/8_6.mp4
#   inflating: /content/data/roi_clips_clean/8_7.mp4
#   inflating: /content/data/roi_clips_clean/9_1.mp4
#   inflating: /content/data/roi_clips_clean/9_2.mp4
#   inflating: /content/data/roi_clips_clean/9_5.mp4
#   inflating: /content/data/roi_clips_clean/9_6.mp4
#   inflating: /content/data/roi_clips_clean/9_7.mp4
#   inflating: /content/data/roi_clips_clean/9_8.mp4

# %%
play_video("/content/data/roi_clips_clean/9_2.mp4", width=300)
# Out:
#   <video width=300 controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#   </video>

# %%
import os
import os.path
import numpy as np
import cv2
from tensorflow.keras.preprocessing.sequence import pad_sequences

data = []
labels = []
max_frames = 30
for dirpath, dirnames, filenames in os.walk("/content/data/roi_clips_clean/"):
    for filename in [f for f in filenames if f.endswith(".mp4")]:
        src_vid_path = (os.path.join(dirpath, filename))
        # print(src_vid_path)
        video_capture = cv2.VideoCapture(src_vid_path)
        frames = []
        while True:
            ret, frame = video_capture.read()
            if not ret:
                break
            # Resize the frame to a fixed size (e.g., 32x32) for consistency
            frame = cv2.resize(frame, (112, 112))
            frames.append(frame)
        video_capture.release()
        if len(frames) > 0:
            # Ensure all frames have the same dimensions by resizing
            frames = [cv2.resize(frame, (112, 112)) for frame in frames]
            # Pad frames to ensure a consistent number of frames
            frames = pad_sequences([frames], maxlen=max_frames, padding='post', truncating='post')[0]
            data.append(frames)
            labels.append(str(src_vid_path.split("/")[-1].split("_")[0]))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, TimeDistributed
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model

data = np.array(data)
labels = np.array(labels)

# %%
# Preprocess the data
data = np.array(data).astype('float32') / 255.0

# One-hot encode the labels
labels = to_categorical(labels, 29)

# %%
labels.size
# Out:
# 4553

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, TimeDistributed, GlobalAveragePooling1D, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model

# data = tf.convert_to_tensor(data, dtype=tf.float32)
# labels = tf.convert_to_tensor(labels, dtype=tf.float32)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.1, random_state=42, shuffle=True)
max_frames = 30

# Reshape the input data to match the model's expected input shape
X_train = X_train.reshape(X_train.shape[0], max_frames, 112, 112, 3)
X_test = X_test.reshape(X_test.shape[0], max_frames, 112, 112, 3)

# Build a simple CNN model
model = Sequential()
model.add(TimeDistributed(Conv2D(32, (3, 3), activation='relu'), input_shape=(max_frames, 112, 112, 3)))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Conv2D(64, (3, 3), activation='relu')))
model.add(Dropout(0.5))  # Add dropout layer
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Flatten()))
model.add(Dropout(0.5))  # Add dropout layer
model.add(GlobalAveragePooling1D())  # Global average pooling over frames
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))  # Add dropout layer
model.add(Dense(29, activation='softmax'))  # Adjust to the number of classes (29 in this case)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=200, batch_size=16, shuffle=True, validation_data=(X_test, y_test))

# Save the model
model.save('/content/alphabet_recognition_model.h5')
# Out:
# Epoch 1/200
# 6/6 [==============================] - 54s 1s/step - loss: 4.7432 - accuracy: 0.0319 - val_loss: 3.3799 - val_accuracy: 0.0317
# Epoch 2/200
# 6/6 [==============================] - 2s 328ms/step - loss: 3.3849 - accuracy: 0.0319 - val_loss: 3.4002 - val_accuracy: 0.0159
# Epoch 3/200
# 6/6 [==============================] - 2s 277ms/step - loss: 3.3563 - accuracy: 0.0745 - val_loss: 3.3916 - val_accuracy: 0.0159
# Epoch 4/200
# 6/6 [==============================] - 2s 282ms/step - loss: 3.3587 - accuracy: 0.0851 - val_loss: 3.3795 - val_accuracy: 0.0317
# Epoch 5/200
# 6/6 [==============================] - 1s 261ms/step - loss: 3.3576 - accuracy: 0.0638 - val_loss: 3.3998 - val_accuracy: 0.0000e+00
# Epoch 6/200
#
ms/step - loss: 0.0429 - accuracy: 1.0000 - val_loss: 8.3733 - val_accuracy: 0.0317
# Epoch 190/200
# 6/6 [==============================] - 1s 250ms/step - loss: 0.0420 - accuracy: 0.9894 - val_loss: 8.8148 - val_accuracy: 0.0317
# Epoch 191/200
# 6/6 [==============================] - 1s 252ms/step - loss: 0.0717 - accuracy: 0.9787 - val_loss: 8.8102 - val_accuracy: 0.0317
# Epoch 192/200
# 6/6 [==============================] - 1s 258ms/step - loss: 0.0322 - accuracy: 0.9894 - val_loss: 8.8707 - val_accuracy: 0.0317
# Epoch 193/200
# 6/6 [==============================] - 1s 251ms/step - loss: 0.0300 - accuracy: 1.0000 - val_loss: 8.9572 - val_accuracy: 0.0317
# Epoch 194/200
# 6/6 [==============================] - 1s 258ms/step - loss: 0.1346 - accuracy: 0.9574 - val_loss: 8.8567 - val_accuracy: 0.0317
# Epoch 195/200
# 6/6 [==============================] - 2s 329ms/step - loss: 0.0811 - accuracy: 0.9681 - val_loss: 8.3704 - val_accuracy: 0.0159
# Epoch 196/200
# 6/6 [==============================] - 2s 333ms/step - loss: 0.0510 - accuracy: 0.9681 - val_loss: 9.0046 - val_accuracy: 0.0159
# Epoch 197/200
# 6/6 [==============================] - 2s 277ms/step - loss: 0.1113 - accuracy: 0.9574 - val_loss: 8.9553 - val_accuracy: 0.0159
# Epoch 198/200
# 6/6 [==============================] - 1s 255ms/step - loss: 0.0730 - accuracy: 0.9894 - val_loss: 9.0326 - val_accuracy: 0.0159
# Epoch 199/200
# 6/6 [==============================] - 1s 256ms/step - loss: 0.0473 - accuracy: 0.9787 - val_loss: 9.3726 - val_accuracy: 0.0159
# Epoch 200/200
# 6/6 [==============================] - 1s 252ms/step - loss: 0.0505 - accuracy: 0.9894 - val_loss: 9.0997 - val_accuracy: 0.0159
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Load the trained model
model = load_model('/content/alphabet_recognition_model.h5')

# Function to preprocess a single video clip
def preprocess_video_clip(video_path, max_frames=30):
    frames = []
    video_capture = cv2.VideoCapture(video_path)

    while True:
        ret, frame = video_capture.read()
        if not ret:
            break
        frame = cv2.resize(frame, (112, 112))
        frames.append(frame)

    video_capture.release()

    if len(frames) > 0:
        frames = [cv2.resize(frame, (112, 112)) for frame in frames]
        frames = pad_sequences([frames], maxlen=max_frames, padding='post', truncating='post')[0]
        frames = np.array(frames).astype('float32') / 255.0
        frames = frames.reshape(1, max_frames, 112, 112, 3)
        return frames
    else:
        return None

# Specify the path to the video clip for prediction
video_path_for_prediction = "/content/data/roi_clips_clean/23_8.mp4"

# Preprocess the video clip
preprocessed_clip = preprocess_video_clip(video_path_for_prediction)

if preprocessed_clip is not None:
    # Make predictions
    predictions = model.predict(preprocessed_clip)

    # Get the predicted class
    predicted_class = np.argmax(predictions)

    # Print or use the predicted class as needed
    print("Predicted Class:", predicted_class)
else:
    print("No frames found in the video clip.")
# Out:
# 1/1 [==============================] - 0s 97ms/step
# Predicted Class: 23
